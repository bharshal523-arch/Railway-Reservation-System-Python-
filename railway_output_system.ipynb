# %% [markdown]
# Welcome Message

# %%
print("Welcome to INDIAN RAILWAYS")
# Out:
# Welcome to INDIAN RAILWAYS

# %% [markdown]
# Creating Variables for Railway Information

# %%
train_name = "Rajdhani Express"
train_number = 22221
source_station = "Mumbai"
destination_station = "Delhi"
ticket_price = 2450.75

# %% [markdown]
# Displaying Welcome Message and Train Details

# %%
print("Welcome to Indian Railway Reservation System")
print("Train Name :", train_name)
print("Train Number :", train_number)
print("Source Station :", source_station)
print("Destination Station :", destination_station)
# Out:
# Welcome to Indian Railway Reservation System
# Train Name : Rajdhani Express
# Train Number : 22221
# Source Station : Mumbai
# Destination Station : Delhi

# %% [markdown]
# Understanding Data Types and Identifiers
#
# Use the type() function to identify data types

# %%
print(type(train_name))
print(type(train_number))
print(type(ticket_price))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %% [markdown]
# Create valid identifiers and literals for passenger information.

# %%
passenger_name = "Rahul Sharma"
seat_number = "B2-45"
is_confirmed = True

# %% [markdown]
# Performing Type Casting
#
# Convert float data into integer data type

# %%
ticket_price_integer = int(ticket_price)
print(type(ticket_price_integer))
# Out:
# <class 'int'>

# %% [markdown]
# Convert integer data into string format

# %%
train_number_string = str(train_number)
print(type(train_number_string))
# Out:
# <class 'str'>

# %% [markdown]
# Adding Comments in Python Program
#
# Add comments for the code

# %%
# Railway Reservation Output System

# Passenger Information
passenger_name = "Rahul Sharma"

# Ticket Confirmation Status
confirmation_status = True

# %% [markdown]
# Simulating Ticket Confirmation Message
#
# Create passenger confirmation variables

# %%
passenger_name = "Rahul Sharma"
seat_number = "B2-45"
confirmation_status = "Confirmed"

# %% [markdown]
# Display ticket confirmation message using formatted output

# %%
print("----------Railway Ticket-------")
print("Passenger_Name : ", passenger_name)
print("Seat_Number :", seat_number)
print("Ticket_Satus :", confirmation_status)
print("-------------------------------")
# Out:
# ----------Railway Ticket-------
# Passenger_Name :  Rahul Sharma
# Seat_Number : B2-45
# Ticket_Satus : Confirmed
# -------------------------------
